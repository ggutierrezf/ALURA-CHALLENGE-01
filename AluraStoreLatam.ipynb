# %% [markdown]
# <a href="https://colab.research.google.com/github/ggutierrezf/ALURA-CHALLENGE-01/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head(2)
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   8  4.60971 -74.08175
# 1  Tarjeta de crédito                   4  6.25184 -75.56359

# %%
# analisis de datos de la tienda 2
tienda2.head(2)
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# 1  Tarjeta de crédito                   4  6.25184 -75.56359

# %%
# analisis de datos de la tienda 3
tienda3.head(2)
# Out:
#            Producto Categoría del Producto     Precio  Costo de envío  \
# 0  Secadora de ropa      Electrodomésticos  1285100.0         66600.0
# 1     Mesa de noche                Muebles   290100.0         13600.0
#
#   Fecha de Compra       Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021  Camila Rivera     Santa Marta             4
# 1      10/02/2021  Maria Alfonso            Cali             3
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# 1  Tarjeta de crédito                   1   3.43722 -76.52250

# %%
# analisis de datos de la tienda 4
tienda4.head(2)
# Out:
#        Producto Categoría del Producto     Precio  Costo de envío  \
# 0  Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1      Cama box                Muebles   473800.0         25400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# 1  Tarjeta de crédito                   2  7.89391 -72.50782

# %%
# unir las cuatro tabalas y eliminar el indice y creando un campo que permita saber de que tienda son los datos
tiendas_unidas = pd.concat([tienda.assign(Origen='Tienda 1'), tienda2.assign(Origen='Tienda 2'), tienda3.assign(Origen='Tienda 3'), tienda4.assign(Origen='Tienda 4')]).reset_index(drop=True)
display(tiendas_unidas.head(2))
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
#
#        Método de pago  Cantidad de cuotas      lat       lon    Origen
# 0  Tarjeta de crédito                   8  4.60971 -74.08175  Tienda 1
# 1  Tarjeta de crédito                   4  6.25184 -75.56359  Tienda 1

# %%
# crear un campo de costo total (precio + envio)
tiendas_unidas['costo total'] = tiendas_unidas['Precio'] + tiendas_unidas['Costo de envío']
display(tiendas_unidas.head(2))
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
#
#        Método de pago  Cantidad de cuotas      lat       lon    Origen  \
# 0  Tarjeta de crédito                   8  4.60971 -74.08175  Tienda 1
# 1  Tarjeta de crédito                   4  6.25184 -75.56359  Tienda 1
#
#    costo total
# 0     171200.0
# 1     200700.0

# %%
# que tipo de datos son?
tiendas_unidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9435 entries, 0 to 9434
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                9435 non-null   object
#  1   Categoría del Producto  9435 non-null   object
#  2   Precio                  9435 non-null   float64
#  3   Costo de envío          9435 non-null   float64
#  4   Fecha de Compra         9435 non-null   object
#  5   Vendedor                9435 non-null   object
#  6   Lugar de Compra         9435 non-null   object
#  7   Calificación            9435 non-null   int64
#  8   Método de pago          9435 non-null   object
#  9   Cantidad de cuotas      9435 non-null   int64
#  10  lat                     9435 non-null   float64
#  11  lon                     9435 non-null   float64
#  12  Origen                  9435 non-null   object
#  13  costo total             9435 non-null   float64
# ...

# %%
# campo fecha de compra transformado en formato fecha
tiendas_unidas['Fecha de Compra'] = pd.to_datetime(tiendas_unidas['Fecha de Compra'], format='%d/%m/%Y')
display(tiendas_unidas.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9435 entries, 0 to 9434
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                9435 non-null   object
#  1   Categoría del Producto  9435 non-null   object
#  2   Precio                  9435 non-null   float64
#  3   Costo de envío          9435 non-null   float64
#  4   Fecha de Compra         9435 non-null   datetime64[ns]
#  5   Vendedor                9435 non-null   object
#  6   Lugar de Compra         9435 non-null   object
#  7   Calificación            9435 non-null   int64
#  8   Método de pago          9435 non-null   object
#  9   Cantidad de cuotas      9435 non-null   int64
#  10  lat                     9435 non-null   float64
#  11  lon                     9435 non-null   float64
#  12  Origen                  9435 non-null   object
#  13  costo total             9435 non-null   float64
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Analisis de la facturacion por cada tienda y por año
tiendas_unidas['Año'] = tiendas_unidas['Fecha de Compra'].dt.to_period('Y')

tabla_ventas_año_tienda = tiendas_unidas.pivot_table(index='Origen', columns='Año', values='costo total', aggfunc='sum')

tabla_ventas_año_tienda_formatted = tabla_ventas_año_tienda.map(lambda x: f'{x:,.0f}'.replace(',', '.') if pd.notnull(x) else '')

display(tabla_ventas_año_tienda_formatted)
# Out:
# Año              2020         2021         2022         2023
# Origen
# Tienda 1  388.679.400  381.340.500  333.427.900  108.810.500
# Tienda 2  337.634.100  369.834.000  377.321.200   91.039.300
# Tienda 3  338.775.400  382.339.200  369.166.600   66.255.000
# Tienda 4  348.376.300  366.421.800  318.377.900   60.517.100

# %%
import matplotlib.pyplot as plt

# graficando las ventas por año
tabla_ventas_año_tienda.transpose().plot(kind='bar', figsize=(5, 4))

plt.title('Ventas Totales por Año y Tienda')
plt.xlabel('Año')
plt.ylabel('Costo Total')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
# total ventas por Categoria y tienda (usando costo total)
tabla_costo_categoria_tienda = tiendas_unidas.pivot_table(index='Categoría del Producto', columns='Origen', values='costo total', aggfunc='sum')

tabla_costo_categoria_tienda.loc['Total'] = tabla_costo_categoria_tienda.sum()

tabla_costo_categoria_tienda_formatted = tabla_costo_categoria_tienda.map(lambda x: f'{x:,.0f}'.replace(',', '.'))

display(tabla_costo_categoria_tienda_formatted)
# Out:
# Origen                        Tienda 1       Tienda 2       Tienda 3  \
# Categoría del Producto
# Artículos para el hogar     13.342.200     15.547.700     15.872.400
# Deportes y diversión        41.411.100     36.621.800     37.516.200
# Electrodomésticos          383.009.200    367.123.400    346.732.100
# Electrónicos               452.457.200    432.645.300    432.631.700
# Instrumentos musicales      96.182.900    110.548.000     81.489.700
# Juguetes                    18.975.200     16.833.000     20.442.800
# Libros                       9.251.900     10.647.000      9.995.100
# Muebles                    197.628.600    185.862.400    211.856.200
# Total                    1.212.258.300  1.175.828.600  1.156.536.200
#
# Origen                        Tienda 4
# Categoría del Producto
# Artículos para el hogar     15.928.600
# Deportes y diversión        35.120.200
# Electrodomésticos          298.282.700
# Electrónicos               431.304.400
# ...

# %%
import matplotlib.pyplot as plt

# Exclude the 'Total' row before plotting
tabla_costo_categoria_tienda_for_plot = tabla_costo_categoria_tienda.drop('Total')

# Plotting the grouped bar chart
tabla_costo_categoria_tienda_for_plot.transpose().plot(kind='bar', figsize=(6, 4))

plt.title('Ventas Totales por Categoría y Tienda (Excluyendo Totales por Tienda)')
plt.xlabel('Origen')
plt.ylabel('Costo Total')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Move the legend outside the plot
plt.legend(title='Categoría del Producto', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# las tres categorias con mas ventas son : Electronico, Electrodomesticos y Muebles.

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
